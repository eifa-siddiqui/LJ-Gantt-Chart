# %%
import subprocess, os, json
os.chdir(r'C:\Users\MECHREVO\Desktop\LJ Gantt Chart\LJ-Gantt-Chart')
def run(cmd):
    proc = subprocess.run(cmd, shell=True, capture_output=True, text=True)
    print('CMD:', cmd)
    print('RET:', proc.returncode)
    print('OUT:
' + proc.stdout)
    print('ERR:
' + proc.stderr)
run('git status --short')
run('git diff -- force-app/main/default/lwc/ganttChart/ganttChart.html force-app/main/default/lwc/ganttChart/ganttChart.js force-app/main/default/lwc/ganttChart/ganttChart.css')
